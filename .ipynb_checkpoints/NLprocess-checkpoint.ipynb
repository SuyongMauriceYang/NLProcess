# %%
import tensorflow
# Out:
# 2022-10-24 00:16:31.611650: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-24 00:16:31.611679: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-24 00:16:31.643278: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-24 00:16:32.311079: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# ...

# %%
# !pip3 install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- --------------------
# absl-py                      1.3.0
# alabaster                    0.7.8
# anyio                        3.6.2
# apturl                       0.5.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.8
# astunparse                   1.6.3
# attrs                        22.1.0
# Babel                        2.6.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       5.0.1
# blinker                      1.4
# Brlapi                       0.7.0
# cachetools                   5.2.0
# ccsm                         0.9.14.1
# certifi                      2019.11.28
# cffi                         1.15.1
# chardet                      3.0.4
# chrome-gnome-shell           0.0.0
# Click                        7.0
# colorama                     0.4.3
# command-not-found            0.3
# ...
